# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
from scipy.optimize import curve_fit
from scipy.optimize import minimize
from scipy.special import hyp2f1
from scipy.integrate import quad
from matplotlib.lines import Line2D

# %% [markdown]
# # Fitting to a single parameter model
#
# The data (Probability of survival) is fitted to
#
# $$ P_R = 1 - e^{- \theta N_0} $$
#
# where $N_0$ is the independent variable

# %%
def model(x, c):
    return 1 - np.exp(-c * x)

def neg_log_lik(theta, x, y, N):
    # enforce theta > 0
    if theta <= 0:
        return np.inf
    
    p = (1 - np.exp(-theta * x))# - theta[1]*x**2)
    # numerical stability
    p = np.clip(p, 1e-12, 1-1e-12)
    
    ll = y * np.log(p) + (N - y) * np.log(1 - p)
    return -np.sum(ll)

def MLE_fit(Ndata_range, PRdata_range): 
    x = np.array(Ndata_range)
    N = np.array([10**4 for xi in x])
    y = np.array([PR*10**4 for PR in PRdata_range])

    # starting value
    theta0 = 0.001

    res = minimize(
        lambda t: neg_log_lik(t, x, y, N),
        x0=[theta0],
        bounds=[(1e-9, None)]
    )

    theta = res.x[0]
    
    PRpred_range = np.array([model(N, theta) for N in Ndata_range])
    
    ss_res = np.sum((PRdata_range - PRpred_range)**2)
    ss_tot = np.sum((PRdata_range - np.mean(PRdata_range))**2)
    r2 = 1 - ss_res/ss_tot
    
    
    return theta, r2
   
dfhigh = pd.read_excel("PR_PopulationSize_HighRep.xlsx", sheet_name="Density_Dependence")
dflow = pd.read_excel("PR_PopulationSize_LowRep.xlsx", sheet_name="Density_Dependence")


fig, ax = plt.subplots(2,3, figsize = (12,6), sharex=True, sharey=True)

for df_ind, df in enumerate([dfhigh,dflow]): 
    for sampling_scheme in range(3) :
        if sampling_scheme == 0 : 
            df_values = df[df.columns[3:]]
        elif sampling_scheme == 1 : 
            df_values = df[df.columns[3:-15]]
        else :
            df_values = df[df.columns[np.array(range(4,len(df.columns)-2,4))]]
        axcur = ax[df_ind][sampling_scheme]
        
        for i in range(df_values.shape[0]):
            if df['Mate-finding'][i] == 'AM' : 
                lbl = 'No Allee effect'
            elif df['Mate-finding'][i] == '0.01' : 
                lbl = 'Weak Allee effect'
            elif df['Mate-finding'][i] == '0.001' :
                lbl = 'Strong Allee effect'
                
            Ndata_range = np.array(df_values.columns, dtype=float )
            PRdata_range = np.array(1-df_values.iloc[i], dtype=float)

            theta, r2 = MLE_fit(Ndata_range, PRdata_range)
            #print("MLE theta =", theta)

            N_range = [ 10**x for x in np.arange(1,7,0.02) ] 
            PR_range = [model(N, theta) for N in N_range]

            lbl = ' $R^2$ = ' + str(round(r2,2))

            axcur.scatter(df_values.columns, 1-df_values.iloc[i], label = lbl, s=15)
            axcur.plot( N_range , PR_range )

        axcur.set_xscale('log')
        axcur.legend()
        

handles, _ = ax[0][0].get_legend_handles_labels()

new_labels = ["No Allee effect", "Weak Allee effect", "Strong Allee effect"]
fig.supxlabel('Population Size (Log scale)', fontsize = 18)
fig.supylabel('Probability of Rescue', fontsize = 18)


ax[0][0].set_title('(a) NoR = $10^4$, NoP = 35 (full range)')
ax[0][1].set_title('(b) NoR = $10^4$, NoP = 20 (truncated)')
ax[0][2].set_title('(c) NoR = $10^4$, NoP = 7 (full ranage)')

ax[1][0].set_title('(d) NoR = $10^2$, NoP = 35 (full range)')
ax[1][1].set_title('(e) NoR = $10^2$, NoP = 20 (truncated)')
ax[1][2].set_title('(f) NoR = $10^2$, NoP = 7 (full ranage)')

plt.tight_layout()

fig.legend(handles,
           new_labels,
           loc="upper center",
           ncol=len(new_labels),
           frameon=True,
          fontsize=15,
          bbox_to_anchor=(0.5, 1.1))

plt.savefig("PR_pos_denisty.png", format='png', bbox_inches="tight")
#plt.legend(loc = 'upper right', bbox_to_anchor = (1,0.9) )

# %%
def neg_log_lik(theta, x, y, N):
    # enforce theta > 0
    if theta[0] <= 0:
        return np.inf
    
    p = 1 - np.exp(-theta[0] * x)# - theta[1]*x**2)
    # numerical stability
    p = np.clip(p, 1e-12, 1-1e-12)
    
    ll = y * np.log(p) + (N - y) * np.log(1 - p)
    return -np.sum(ll)

def model(x, theta):
    return 1 - np.exp(-theta[0] * x  )#- theta[1]*x**2 )

df = pd.read_excel("PR_PopulationSize_HighRep.xlsx", sheet_name="Density_Dependence")
df_values = df[df.columns[3:]]

for i in range(df_values.shape[0]):
    if df['Mate-finding'][i] == 'AM' : 
        lbl = 'No Allee'
    elif round(float(df['Mate-finding'][i]),3) == 0.01 : 
        lbl = 'Weak Allee effect'
    elif round(float(df['Mate-finding'][i]),3) == 0.001 : 
        lbl = 'Strong Allee effect'
    
    Ndata_range = np.array(df_values.columns, dtype=float )
    PRdata_range = np.array(1-df_values.iloc[i], dtype=float)
    
    x = np.array(Ndata_range)
    N = np.array([10**4 for xi in x])
    y = np.array([PR*10**4 for PR in PRdata_range])

    # starting value
    theta = [0.001,0.001]
    

    res = minimize(
        lambda theta : neg_log_lik(theta, x, y, N),
        x0=theta,
        bounds=[(1e-9, None),(0,None)]
    )

    theta = res.x
    #theta1 = res.x[1]
    
    print("MLE theta =", theta)
    
    N_range = [ 10**x for x in np.arange(1,7,0.02) ] 
    PR_range = [model(N, theta) for N in N_range]
    
    PRpred_range = np.array([model(N, theta) for N in Ndata_range])
    
    ss_res = np.sum((PRdata_range - PRpred_range)**2)
    ss_tot = np.sum((PRdata_range - np.mean(PRdata_range))**2)
    r2 = 1 - ss_res/ss_tot
    lbl += ' $R^2$ = ' + str(round(r2,2))
    
    #plt.scatter(df_values.columns, 1-df_values.iloc[i], label = lbl, s=15)
    #plt.plot( N_range , PR_range )
    plt.scatter(Ndata_range, PRdata_range-PRpred_range , label = lbl, s=15  )
    
plt.xscale('log')
#plt.ylim([-1.05,1.05])
#plt.yscale('log')

plt.legend(loc = 'upper left')#, bbox_to_anchor = (1,0.9) )
plt.xlabel("Population Size (Log Scale)", fontsize=13)
plt.ylabel(r"$P_\text{rescue}(\text{sim}) - P_\text{rescue}(\text{fit})$", fontsize=13)
plt.savefig("PR_pos_denisty_diff.png", format='png', bbox_inches="tight")
plt.show()

df = pd.read_excel("PR_PopulationSize_HighRep_BD.xlsx", sheet_name="DensityDependence")
df_values = df[df.columns[3:]]

clrs = ['#2ca02c', '#ff7f0e', '#1f77b4']
for i in range(df_values.shape[0]):
    if float(df['CarryingCapacity'][i]) == np.inf : 
        lbl = 'No Competition'
    elif round(float(df['CarryingCapacity'][i])) == 10**4 : 
        lbl = 'Strong Competition'
    elif round(float(df['CarryingCapacity'][i])) == 3*10**4 : 
        lbl = 'Weak Competition'
    
    Ndata_range = np.array(df_values.columns, dtype=float )
    PRdata_range = np.array(1-df_values.iloc[i], dtype=float)
    
    x = np.array(Ndata_range)
    N = np.array([10**4 for xi in x])
    y = np.array([PR*10**4 for PR in PRdata_range])

    # starting value
    theta = [0.001,0.001]
    

    res = minimize(
        lambda theta : neg_log_lik(theta, x, y, N),
        x0=theta,
        bounds=[(1e-9, None),(0,None)]
    )

    theta = res.x
    #theta1 = res.x[1]
    
    print("MLE theta =", theta)
    
    N_range = [ 10**x for x in np.arange(1,7,0.02) ] 
    PR_range = [model(N, theta) for N in N_range]
    
    PRpred_range = np.array([model(N, theta) for N in Ndata_range])
    
    ss_res = np.sum((PRdata_range - PRpred_range)**2)
    ss_tot = np.sum((PRdata_range - np.mean(PRdata_range))**2)
    r2 = 1 - ss_res/ss_tot
    lbl += ' $R^2$ = ' + str(round(r2,2))
    
    #plt.scatter(df_values.columns, 1-df_values.iloc[i], label = lbl, s=15)
    #plt.plot( N_range , PR_range )
    plt.scatter(Ndata_range, PRdata_range-PRpred_range , label = lbl, s=15, color = clrs[i]  )
    
plt.xscale('log')
#plt.ylim([-1.05,1.05])
#plt.yscale('log')

plt.legend(loc = 'upper left')#, bbox_to_anchor = (1,0.9) )
plt.xlabel("Population Size (Log Scale)", fontsize=13)
plt.ylabel(r"$P_\text{rescue}(\text{sim}) - P_\text{rescue}(\text{fit})$", fontsize=13)
plt.savefig("PR_neg_denisty_diff.png", format='png', bbox_inches="tight")
plt.show()
# Out:
# MLE theta = [0.00058078 0.001     ]
# MLE theta = [0.00033929 0.001     ]
# MLE theta = [6.77023097e-05 1.00000000e-03]
# MLE theta = [3.92261271e-05 1.00000000e-03]
# MLE theta = [0.00012905 0.001     ]
# MLE theta = [0.00047311 0.001     ]

# %%
def hyp2f1_pq(p,q,x):
    return hyp2f1(q,p,1+p,x)

def pest(t,bw,dw,bm,dm,K,N0, var ='t'): 
    rw = bw-dw 
    rm = bm-dm 
    Kw = rw/bw*K
    A = Kw/N0 - 1 
    if var == 't' : 
        x = -np.exp(rw*t)/A
    else : 
        x = t
    Jt = (bm+dm)/rm * hyp2f1_pq(-rm/rw, -bm/bw, x) - bm/bw * x/(1-rm/rw) * hyp2f1_pq(1-rm/rw, 1-bm/bw,x) 
    Jt = Jt/  ( 1 -x )**(bm/bw)
    return 2*(1+Jt)**(-1)

def Pres(bw,dw,bm,dm,K,N0,mu) : 
    def integrand(t): 
        rw = bw-dw
        Kw = (1-dw/bw)*K
        nwt = Kw*N0*np.exp(rw*t)/(N0*np.exp(rw*t) + Kw-N0)
        return mu*nwt*pest(t,bw,dw,bm,dm,K,N0)
    
    
    Pres_time = 1- np.exp( - quad(integrand, 0, np.inf, limit = 500)[0] )
    rw = bw-dw
    Kw = (1-dw/bw)*K
    def integrand_alt(x): 
        rw = bw-dw
        Kw = (1-dw/bw)*K
        return mu*Kw*pest(x,bw,dw,bm,dm,K,N0, var='x')/(rw*(1-x))    
    
    n0 = N0/K 
    Pres_density = 1- np.exp( - quad(integrand_alt, 0, n0/(n0-rw/bw))[0] )
    return Pres_time, Pres_density 

def Pres_theory(bw,dw,bm,dm,K,N0,mu) : 
    rw = bw-dw
    rm = bm-dm 
    n0 = N0/K 
    x0 = n0/(n0 - rw/bw)
    y = min([0.8,x0]) 
    C0 = 1-dm/bm
    C1 = C0 * dm/bw*rw/(rm-rw)
    H = (bm+dm)/rm * hyp2f1_pq(-rm/rw, -bm/bw, 1) - bm/bw * 1/(1-rm/rw) * hyp2f1_pq(1-rm/rw, 1-bm/bw,1) 
    E1 = -C1*y  - (C1+C0)*np.log(1-y) 
    E2 = 2*H**(-1)*bw /bm*( (1-y)**(bm/bw) - (1-x0)**(bm/bw) )
    
    return 1 - np.exp( -mu*K/bw*(E1 + E2) )

# %%
def model1(x, theta):
    return 1 - np.exp(-theta[0] * x)
def model2(x, theta):
    return 1 - np.exp(-theta[0] * x/(x+theta[1]) )


def neg_log_lik(model, theta, x, y, N):
    # enforce theta > 0
    if theta[0] <= 0:
        return np.inf
    
    p = model(x,theta) #(1 - theta[1]*np.exp(-theta[0] * x))# - theta[1]*x**2)
    # numerical stability
    p = np.clip(p, 1e-12, 1-1e-12)
    
    ll = y * np.log(p) + (N - y) * np.log(1 - p)
    return -np.sum(ll)


def MLE_fit(Ndata_range, PRdata_range, model, theta0, bounds): 
    x = np.array(Ndata_range)
    N = np.array([10**4 for xi in x])
    y = np.array([PR*10**4 for PR in PRdata_range])

    # starting value
    #theta0 = [0.001, 1]
    
    res = minimize(
        lambda t: neg_log_lik(model, t, x, y, N),
        x0=theta0,
        bounds=bounds#[(1e-9, None),(0,1)]
    )

    theta = res.x
    
    PRpred_range = np.array([model(N, theta) for N in Ndata_range])
    
    ss_res = np.sum((PRdata_range - PRpred_range)**2)
    ss_tot = np.sum((PRdata_range - np.mean(PRdata_range))**2)
    r2 = 1 - ss_res/ss_tot
    
    
    return theta, r2, neg_log_lik(model, theta, x, y, N)

   
dfhigh = pd.read_excel("PR_PopulationSize_HighRep_BD.xlsx", sheet_name="DensityDependence")
dflow = pd.read_excel("PR_PopulationSize_LowRep_BD.xlsx", sheet_name="DensityDependence")


fig, ax = plt.subplots(2,3, figsize = (12,6), sharex=True, sharey=True)
#Pres_rng = [Pres(bw,dw,bm,dm,K,N0,mu) for N0 in N0_rng]
clrs = ['#2ca02c', '#ff7f0e', '#1f77b4']
 
for df_ind, df in enumerate([dfhigh,dflow]): 
    for sampling_scheme in range(3) :
        if sampling_scheme == 0 : 
            df_values = df[df.columns[2:]]
        elif sampling_scheme == 1 : 
            df_values = df[df.columns[2:-10]]
        else :
            df_values = df[df.columns[np.array(range(4,len(df.columns)-2,4))]]
        axcur = ax[df_ind][sampling_scheme]
        
        for i in range(df_values.shape[0]):
            if df['CarryingCapacity'][i] == "inf": 
                lbl = 'No competition'
            else :
                lbl = 'Competition'

            Ndata_range = np.array(df_values.columns, dtype=float )
            PRdata_range = np.array(1-df_values.iloc[i], dtype=float)
            
            theta0 = [0.001]
            bounds = [(1e-9,None)]
            theta, r2_1, nll1 = MLE_fit(Ndata_range, PRdata_range, model1, theta0, bounds)
            #print("MLE theta =", theta)
            
            N_range = [ 10**x for x in np.arange(1,5,0.02) ] 
            PR_range = [model1(N, theta) for N in N_range]
            
            lbl =  str(round(r2_1,2))
            
            axcur.plot( N_range , PR_range, color = clrs[i])

            theta0 = [0.001, 1]
            bounds = [(1e-9,None),(None,None)]
            theta, r2_2, nll2 = MLE_fit(Ndata_range, PRdata_range, model2, theta0, bounds)
            #print("MLE theta =", theta)

            N_range = [ 10**x for x in np.arange(1,5,0.02) ] 
            PR_range = [model2(N, theta) for N in N_range]

            lbl += ", " + str(round(r2_2,2))
            
            AIC1 = np.log(len(df_values.columns)) + 2*nll1
            AIC2 = 2*np.log(len(df_values.columns)) + 2*nll2
            
            ratio1 = np.exp((min(AIC1,AIC2)-AIC1)/2)
            ratio2 = np.exp((min(AIC1,AIC2)-AIC2)/2)
            prob2 = ratio2/(ratio1+ratio2)
            lbl += ", " + str(round(prob2,4)) #str(round(ratio1,2)) + ", " + str(round(ratio2,2))
            #axcur.scatter(df_values.columns, 1-df_values.iloc[i], s=15, color = clrs[i])
            axcur.plot( N_range , PR_range, color = clrs[i], linestyle = '--' )
            
            axcur.scatter(df_values.columns, 1-df_values.iloc[i], s=15, color = clrs[i], label = lbl)
            

        axcur.set_xscale('log')
        axcur.legend(title = r'$R^2_1,R^2_2$,Prob2')
        bw = 0.5 + np.log(0.95)/2
        bm = 0.5 + np.log(1.15)/2
        dw = 0.5 - np.log(0.95)/2
        dm = 0.5 - np.log(1.15)/2
        mu = 10**(-4)
        K = 3*10**4
        N0_rng = [10**x for x in np.arange(1,5,0.02)]
        #axcur.plot(N0_rng, [Pres(bw,dw,bm,dm,K,N0,mu) for N0 in N0_rng], linestyle = '--', color = 'red')


handles, _ = ax[0][0].get_legend_handles_labels()

new_labels = ["Strong competition", "Weak competition", "No competition"]
fig.supxlabel('Population Size (Log scale)', fontsize = 18)
fig.supylabel('Probability of Rescue', fontsize = 18)


ax[0][0].set_title('(a) NoR = $10^4$, NoP = 35 (full range)')
ax[0][1].set_title('(b) NoR = $10^4$, NoP = 20 (truncated)')
ax[0][2].set_title('(c) NoR = $10^4$, NoP = 7 (full ranage)')

ax[1][0].set_title('(d) NoR = $10^2$, NoP = 35 (full range)')
ax[1][1].set_title('(e) NoR = $10^2$, NoP = 20 (truncated)')
ax[1][2].set_title('(f) NoR = $10^2$, NoP = 7 (full ranage)')

plt.tight_layout()

fig.legend(handles,
           new_labels,
           loc="upper center",
           ncol=len(new_labels),
           frameon=True,
          fontsize=15,
          bbox_to_anchor=(0.5, 1.1))
custom_handles = [
    Line2D([0], [0], marker='o', color='gray',
           markerfacecolor='gray', markersize=10, linestyle='None'),
    Line2D([0], [0], color='gray', linewidth=2),
    Line2D([0], [0], color='gray', linewidth=2, linestyle='--')
]

custom_labels = [
    "Simulation",
    "Best Fit (Model 1)",
    "Best Fit (Model 2)"
]

# --- second legend ---
leg2 = fig.legend(
    custom_handles,
    custom_labels,
    loc="upper center",
    ncol=3,
    frameon=True,
    fontsize=15,
    bbox_to_anchor=(0.5, 1.2)
)

# Important: keep both legends
fig.add_artist(leg2)


plt.savefig("PR_neg_denisty.png", format='png', bbox_inches="tight")
#plt.legend(loc = 'upper right', bbox_to_anchor = (1,0.9) )

# %%
minimize?

# %%
df = pd.read_excel("PR_PopulationSize_HighRep_ConstDen_BD.xlsx", sheet_name="DensityDependence")
df_values = df[df.columns[3:]]

for i in range(df_values.shape[0]):
    n0 = round(float(df['CarryingCapacity'][i]),2)
    if n0 == 0.0: 
        lbl = 'No competition'
    elif n0 == 0.1:
        lbl = r'Weak competition ($\frac{N0}{K} = 0.1$)'
    elif n0 == 1.0:
        lbl = r'Strong competition ($\frac{N0}{K} = 1)$'
    
    Ndata_range = np.array(df_values.columns, dtype=float )
    PRdata_range = np.array(1-df_values.iloc[i], dtype=float)
    
    x = np.array(Ndata_range)
    N = np.array([10**4 for xi in x])
    y = np.array([PR*10**4 for PR in PRdata_range])

    # starting value
    theta0 = 0.001
    

    res = minimize(
        lambda theta : neg_log_lik(theta, x, y, N),
        x0=[theta0],
        bounds=[(1e-9, None)]
    )

    theta0 = res.x[0]
    
    
    print("MLE theta =", theta0)
    
    N_range = [ 10**x for x in np.arange(1,7,0.02) ] 
    PR_range = [model(N, theta0) for N in N_range]
    
    PRpred_range = np.array([model(N, theta0) for N in Ndata_range])
    
    ss_res = np.sum((PRdata_range - PRpred_range)**2)
    ss_tot = np.sum((PRdata_range - np.mean(PRdata_range))**2)
    r2 = 1 - ss_res/ss_tot
    lbl += ' $R^2$ = ' + str(round(r2,2))
    
    plt.scatter(df_values.columns, 1-df_values.iloc[i], label = lbl, s=15)
    plt.plot( N_range , PR_range )
    
plt.xscale('log')
plt.ylim([-0.05,1.05])
#plt.yscale('log')

plt.legend(loc = 'lower right' )
plt.xlabel("Population Size (Log Scale)", fontsize = 13)
plt.ylabel(r"Probability of Rescue $P_\text{res}$", fontsize = 13)

plt.savefig("PR_neg_const_density.png", format='png', bbox_inches="tight")
# Out:
# MLE theta = 0.00047310895039154516
# MLE theta = 0.0003045832535150239
# MLE theta = 7.5999421337946e-05

# %% [markdown]
# # Supplementary Analysis - Alternative model for competition

# %%
def model(x, theta):
    #print(x)
    """
    if x < theta[3]:
        return 1- np.exp(-theta[0]*x)
    else: 
        return 1 - theta[1]*np.exp(theta[2]*(1/x))
    """
    return 1-np.exp(-theta[0]*(1+theta[1]/x)**(-1) )
   

def neg_log_lik(theta, x, y, N):
    # enforce theta > 0
    if theta[0] <= 0:
        return np.inf
    
    p = np.array( [ model(xval,theta) for xval in x] ) #theta[1]*(1 - np.exp(-theta[0] * x))# - theta[1]*x**2)
    # numerical stability
    p = np.clip(p, 1e-12, 1-1e-12)
    
    ll = y * np.log(p) + (N - y) * np.log(1 - p)
    return -np.sum(ll)


def MLE_fit(Ndata_range, PRdata_range): 
    x = np.array(Ndata_range)
    N = np.array([10**4 for xi in x])
    y = np.array([PR*10**4 for PR in PRdata_range])

    # starting value
    #theta0 = [0.001, 0.2, 100, 2.3*10**3]
    theta0 = [0.001, 1]
    
    res = minimize(
        lambda t: neg_log_lik(t, x, y, N),
        x0=theta0,
        #bounds=[(1e-9, None),(0,1),(1e-9, None),(10**2,None)]
        bounds=[(1e-9, None),(None,None)]
    )

    theta = res.x
    
    PRpred_range = np.array([model(N, theta) for N in Ndata_range])
    
    ss_res = np.sum((PRdata_range - PRpred_range)**2)
    ss_tot = np.sum((PRdata_range - np.mean(PRdata_range))**2)
    r2 = 1 - ss_res/ss_tot
    
    
    return theta, r2


bw = 0.5 + np.log(0.95)/2
bm = 0.5 + np.log(1.15)/2
dw = 0.5 - np.log(0.95)/2
dm = 0.5 - np.log(1.15)/2
mu = 10**(-4)
K = 3*10**4



   
#dfhigh = pd.read_excel("PR_PopulationSize_HighRep_BD.xlsx", sheet_name="DensityDependence")
#df = pd.read_excel("PR_PopulationSize_LowRep_BD.xlsx", sheet_name="DensityDependence")


fig, axcur = plt.subplots(1,1, figsize = (4,4), sharex=True, sharey=True)
#Pres_rng = [Pres(bw,dw,bm,dm,K,N0,mu) for N0 in N0_rng]
clrs = ['#2ca02c', '#ff7f0e', '#1f77b4']
 
df_values = df[df.columns[2:]]
        
        
for i in range(df_values.shape[0]):
    #if i != 0 : 
    #    continue
    if df['CarryingCapacity'][i] == "inf": 
        lbl = 'No competition'
    else :
        lbl = 'Competition'

    Ndata_range = np.array(df_values.columns, dtype=float )
    PRdata_range = np.array(1-df_values.iloc[i], dtype=float)

    theta, r2 = MLE_fit(Ndata_range, PRdata_range)
    print("MLE theta =", theta)

    N_range = [ 10**x for x in np.arange(1,5,0.02) ] 
    PR_range = [model(N,theta) for N in N_range]

    lbl = ' $R^2$ = ' + str(round(r2,2))

    axcur.scatter(df_values.columns, 1-df_values.iloc[i], label = lbl, s=15, color = clrs[i])
    axcur.plot( N_range , PR_range, color = clrs[i] )

axcur.set_xscale('log')
axcur.legend()

N0_rng = [10**x for x in np.arange(1,5,0.02)]
axcur.plot(N0_rng, [Pres(bw,dw,bm,dm,K,N0,mu) for N0 in N0_rng], linestyle = '--', color = 'red')


handles, _ = ax[0][0].get_legend_handles_labels()

new_labels = ["Strong competition", "Weak competition", "No competition"]
fig.supxlabel('Population Size (Log scale)', fontsize = 18)
fig.supylabel('Probability of Rescue', fontsize = 18)

fig.suptitle('NoR = $10^2$, NoP = 35 (full range)')
plt.tight_layout()

fig.legend(handles,
           new_labels,
           loc="upper center",
           ncol=len(new_labels),
           frameon=True,
          fontsize=15,
          bbox_to_anchor=(0.5, 1.1))



plt.ylim([-0.1,1.1])
#plt.savefig("PR_neg_denisty.png", format='png', bbox_inches="tight")
#plt.legend(loc = 'upper right', bbox_to_anchor = (1,0.9) )
# Out:
# MLE theta = [9.27367216e-01 1.74248063e+03]
# MLE theta = [2.77355389e+00 6.08208187e+03]
# MLE theta = [2.52750185e+01 4.79459334e+04]
# (-0.1, 1.1)

# %%
-rm/(rm-rw)
# Out:
# -0.731526362445344

# %%
rw = bw-dw
rm = bm-dm
C0 = 1-dm/bm
C1 = C0 * dm/bw*rw/(rm-rw)
H = (bm+dm)/rm * hyp2f1_pq(-rm/rw, -bm/bw, 1) - bm/bw * 1/(1-rm/rw) * hyp2f1_pq(1-rm/rw, 1-bm/bw,1) 

theta = [mu*C1/rw, 0.4, -2*mu*K**2*rw/(H*bm*bw), 0.8 ]
print(theta)
# Out:
# [0.0001163945130789755, 0.4, 2798.4278121753896, 0.8]

# %% [markdown]
# # Individual Simulations

# %%
def birthdeath(nw0, nm0, bw, bm, dw, dm, mu, K, timeseries = False):
    """
    Gillespie algorithm for two types (nw, nm) with:
        Birthw: nw → nw + 1 at rate bw * (1 - (nw+nm)/K) * nw
        Birthm: nm → nm + 1 at rate bm * (1 - (nw+nm)/K) * nm
        Deathw: nw → nw - 1 at rate dw * nw
        Deathm: nm → nm - 1 at rate dm * nm

    Stops when:
        1. nw + nm = 0   (extinction)
        2. nw + nm ≥ Ncap   (rescued)
    """

    np.random.seed()

    t = 0.0
    nw = nw0
    nm = nm0

    if timeseries :
        times = [t]
        trajw = [nw]
        trajm = [nm]
    
    Ext = 0 
    while True:
        if nw%100 == 0 :
            print(nw, nm)
        N = nw + nm

        if N == 0 :
            Ext = 1
            break
        
        if nm >= 0.5*K and nm/N > 0.6:
            Ext = 0
            break
        
        if K == np.inf : 
            growthfactor = 1 
        else : 
            growthfactor = max(0.0, 1 - N / K)

        birth_w = bw * growthfactor * nw        # W birth
        birth_m = bm * growthfactor * nm         # M birth
        death_w = dw * nw                    # W death
        death_m = dm * nm                    # M death
        mutation = mu * nw
        #print(birth_w, birth_m, death_w, death_m, mutation)
        rates = np.array([birth_w, birth_m, death_w, death_m, mutation])
        total_rate = rates.sum()

        if total_rate <= 0:
            break

        # Time step
        dt = np.random.exponential(1 / total_rate)
        t += dt

        # Select event
        r = np.random.rand() * total_rate

        if r < birth_w:
            nw += 1
        elif r < birth_w + birth_m:
            #print("1")
            nm += 1
        elif r < birth_w + birth_m + death_w:
            nw -= 1
        elif r < birth_w + birth_m + death_w + death_m :
            #print("2")
            nm -= 1
        else : 
            #print("3")
            nm += 1 
            nw -= 1 
            
        if timeseries : 
            times.append(t)
            trajw.append(nw)
            trajm.append(nm)
    if timeseries:
        return times, trajw, trajm, Ext 
    return Ext

# %%
def p_est_num(t, b_m, d_m, b_w, d_w, K, N0):
    """
    Numerically evaluates the establishment probability p_est(t)
    without using hypergeometric functions.
    
    Parameters
    ----------
    t : float
        Time at which the mutant arises
    b_m : float
        Mutant birth rate
    d_m : float
        Mutant death rate
    b_w : float
        Wildtype birth rate
    d_w : float
        Wildtype death rate
    K : float
        Carrying capacity of the environment
    N0 : float
        Initial wildtype population
        
    Returns
    -------
    p : float
        Establishment probability
    """
    # Wildtype growth rate and carrying capacity
    r_w = b_w - d_w
    K_w = r_w * K / b_w
    A = K_w/N0 - 1 
    
    # Mutant birth rate function
    def lambda_m(tau):
        n_w = K_w * N0 / (N0 + (K_w - N0) * np.exp(-r_w * tau))
        return b_m * (1 - n_w/K)
    
    # Integrand for the outer integral
    def integrand(tp):
        inner_integral = b_m - d_m - b_m*r_w/b_w *(tp-t) - b_m/b_w * np.log( (N0 + (K_w-N0)*np.exp(-r_w*tp))/(N0 + (K_w-N0)*np.exp(-r_w*t))  )
        print((lambda_m(tp) + d_m) * np.exp(-inner_integral))
        
        return (lambda_m(tp) + d_m) * np.exp(-inner_integral)
    # Outer integral J(t)
    output = quad(integrand, t, np.inf)
    
    # Establishment probability
    return output[0]

N0 = 1000
trng = np.arange(0,500,0.1)
bw = 0.5 + np.log(0.95)/2
bm = 0.5 + np.log(1.05)/2
dw = 0.5 - np.log(0.95)/2
dm = 0.5 - np.log(1.05)/2
mu = 10**(-4)
K = 10**4 

#prng = [ p_est_num(t, bw, dw, bm, dm, K, N0) for t in trng ]
#plt.plot(trng, prng)

# %%
def hyp2f1_pq(p,q,x):
    return hyp2f1(q,p,1+p,x)

def pest(t,bw,dw,bm,dm,K,N0, var ='t'): 
    rw = bw-dw 
    rm = bm-dm 
    Kw = rw/bw*K
    A = Kw/N0 - 1 
    if 't' : 
        x = -np.exp(rw*t)/A
    else : 
        x = t
    Jt = (bm+dm)/rm * hyp2f1_pq(-rm/rw, -bm/bw, x) - bm/bw * x/(1-rm/rw) * hyp2f1_pq(1-rm/rw, 1-bm/bw,x) 
    Jt = Jt/  ( 1 -x )**(bm/bw)
    return 2*(1+Jt)**(-1)

N0 = 10**4
trng = np.arange(0,500,0.1)
bw = 0.5 + np.log(0.95)/2
bm = 0.5 + np.log(1.5)/2
dw = 0.5 - np.log(0.95)/2
dm = 0.5 - np.log(1.5)/2
mu = 10**(-4)
K = 10**4 

pest_rng = [pest(t,bw,dw,bm,dm,K,N0) for t in trng]


rm = bm-dm
rw = bw-dw
A = K*rw/(bw*N0) - 1
xrng = [-np.exp(rw*t)/A for t in trng]

#plt.ylim(-0.01,1.01)

# %%
def hyp2f1_pq(p,q,x):
    return hyp2f1(q,p,1+p,x)

def pest(t,bw,dw,bm,dm,K,N0, var ='t'): 
    rw = bw-dw 
    rm = bm-dm 
    Kw = rw/bw*K
    A = Kw/N0 - 1 
    if var == 't' : 
        x = -np.exp(rw*t)/A
    else : 
        x = t
    Jt = (bm+dm)/rm * hyp2f1_pq(-rm/rw, -bm/bw, x) - bm/bw * x/(1-rm/rw) * hyp2f1_pq(1-rm/rw, 1-bm/bw,x) 
    Jt = Jt/  ( 1 -x )**(bm/bw)
    return 2*(1+Jt)**(-1)

def Pres(bw,dw,bm,dm,K,N0,mu) : 
    def integrand(t): 
        rw = bw-dw
        Kw = (1-dw/bw)*K
        nwt = Kw*N0*np.exp(rw*t)/(N0*np.exp(rw*t) + Kw-N0)
        return mu*nwt*pest(t,bw,dw,bm,dm,K,N0)
    
    
    Pres_time = 1- np.exp( - quad(integrand, 0, np.inf, limit = 500)[0] )
    rw = bw-dw
    Kw = (1-dw/bw)*K
    def integrand_alt(x): 
        rw = bw-dw
        Kw = (1-dw/bw)*K
        return mu*Kw*pest(x,bw,dw,bm,dm,K,N0, var='x')/(rw*(1-x))    
    
    n0 = N0/K 
    Pres_density = 1- np.exp( - quad(integrand_alt, 0, n0/(n0-rw/bw))[0] )
    return Pres_time, Pres_density 

def Pres_theory(bw,dw,bm,dm,K,N0,mu) : 
    rw = bw-dw
    rm = bm-dm 
    n0 = N0/K 
    x0 = n0/(n0 - rw/bw)
    #y = min([0.8,x0]) 
    C0 = 1-dm/bm
    C1 = C0*rw/(rm-rw)* dm/bw
    H = (bm+dm)/rm * hyp2f1_pq(-rm/rw, -bm/bw, 1) - bm/bw * 1/(1-rm/rw) * hyp2f1_pq(1-rm/rw, 1-bm/bw,1) 
    y_cut = (2*H**(-1) - C0)/(2*H**(-1) + C1)
    
    y = min(y_cut,x0)
    E1 = -C1*y  - (C1+C0)*np.log(1-y) 
    E2 = 2*H**(-1)*bw /bm*( (1-y)**(bm/bw) - (1-x0)**(bm/bw) )
    
    return 1 - np.exp( -mu*K/bw*(E1 + E2) )

def Pres_theory2(bw,dw,bm,dm,K,N0,mu) : 
    rw = bw-dw
    rm = bm-dm 
    n0 = N0/K 
    x0 = n0/(n0 - rw/bw)
    C0 = 1-dm/bm
    C1 = C0 *rw/(rm-rw)#* dm/bw
    y = 0.7
    H =rw/rm *1/(rw-rm)- 1* 1/(1-rm/rw)#(bm+dm)/rm * hyp2f1_pq(-rm/rw, -bm/bw, 1) - bm/bw * 1/(1-rm/rw) * hyp2f1_pq(1-rm/rw, 1-bm/bw,1) 
    E1 = -C1*y  - (C1+C0)*np.log(1-y) 
    E2 = 2*H**(-1)*bw/bm*( (1-y)**(bm/bw)  )
    
    P_infty = 1 - np.exp( -mu*K/bw*(E1 + E2) ) #- 0.01
    
    #return model(N0,[mu*C1/rw, 1-0.58, -2*mu*K**2*rw/(H*bw*bm), -y/(1-y)*rw/bw*K ])
    y_cut = (2*H**(-1) - C0)/(2*H**(-1) + C1)
    if x0 < y_cut:
        return 1- np.exp(-mu*K/rw*C1*n0)
    else: 
        return 1 - (1-P_infty)*np.exp(-2*mu*K**2*rw/(H*bw*bm)*(1/N0))
    
def Pres_theory3(bw,dw,bm,dm,K,N0,mu) : 
    rw = bw-dw
    rm = bm-dm 
    n0 = N0/K 
    x0 = n0/(n0 - rw/bw)
    C0 = 2*rm #1-dm/bm
    C1 = C0 *rw/(rm-rw)#* dm/bw
    y = 0.7
    H = rw/rm *1/(rw-rm)- 1* 1/(1-rm/rw)#(bm+dm)/rm * hyp2f1_pq(-rm/rw, -bm/bw, 1) - bm/bw * 1/(1-rm/rw) * hyp2f1_pq(1-rm/rw, 1-bm/bw,1) 
    E1 = -C1*y  - (C1+C0)*np.log(1-y) 
    E2 = 2*H**(-1)*( (1-y) )
    
     #1 - np.exp( -mu*K/bw*(E1 + E2) ) #- 0.01
    
    y_cut = (2*H**(-1) - C0)/(2*H**(-1) + C1)
    P_infty = Pres(bw,dw,bm,dm,K,10**10,mu)[0]  #1 - np.exp( -mu*K/bw*(E1 + E2)) #1-np.exp(-mu*K*rm/bw*(1-rm/(rm-rw)*np.log(1-y_cut)))
    A2 = -rw/bw*K
    A1 =  -np.log(1-P_infty) #- mu*K/bw*C1
    A2 = -rw*A1/(mu*C0)
    #print(A1, A2)
    return  1 - np.exp(- A1*N0/(N0+A2) ) #P_infty*(1- np.exp(-mu*K/rw*C1*n0/P_infty))
    #else: 
        #return 1 - (1-P_infty)*np.exp(-2*mu*K**2*rw/(H*bw*bm)*(1/N0))
    

N0_rng = [ round(10**x) for x in np.arange(1,10,0.2) ] 
K = 10**4
colors = ["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728", "#9467bd", "#8c564b", "#e377c2"]

fig, ax = plt.subplots(1,1,figsize = (5,4))
for sm_ind, sm in enumerate([0.01,0.05,0.15, 0.5]) : 
    bw = 0.5 + np.log(0.95)/2
    bm = 0.5 + np.log(1 + sm)/2
    dw = 0.5 - np.log(0.95)/2
    dm = 0.5 - np.log(1+ sm)/2
    mu = 10**(-4)
    rw = bw-dw
    rm = bm-dm

    Pres_rng = [Pres(bw,dw,bm,dm,K,N0,mu) for N0 in N0_rng]
    Pres_rng = np.array(Pres_rng) 
    Pres_rng = np.transpose(Pres_rng)

    ax.scatter(N0_rng, Pres_rng[0], facecolors='none', edgecolor = colors[sm_ind], s=5, label = str(sm)) #, label = 'Time Integral'
    ax.plot(N0_rng, Pres_rng[1], linestyle = '--', color = colors[sm_ind]) #, label = 'Density Integral'

    #plt.plot(N0_rng, [Pres_theory(bw,dw,bm,dm,K,N0,mu) for N0 in N0_rng], label = 'Approximation 1')
    #plt.plot(N0_rng, [Pres_theory2(bw,dw,bm,dm,K,N0,mu) for N0 in N0_rng], label = 'Approximation 2')

    ax.plot(N0_rng, [Pres_theory3(bw,dw,bm,dm,K,N0,mu) for N0 in N0_rng], color = colors[sm_ind]) #, label = 'Model 2 (Exact $P_\text{res}$)'


#fig, ax = plt.subplots()

# ---- your existing plot code ----
# ax.plot(x, y)

# ---- custom legend handles ----
legend_elements = [
    Line2D([0], [0], color='gray', lw=2, linestyle='-',
           label=r'Approximation (Exact $P_\infty$)'),
    Line2D([0], [0], color='gray', lw=2, linestyle='--',
           label='Exact Density Integral'),
    Line2D([0], [0], marker='o', color='gray',
           markerfacecolor='none', linestyle='None',
           label='Exact Time Integral')
]

fig.legend(handles=legend_elements, loc = 'upper center', ncol=len(legend_elements), bbox_to_anchor=(0.5, 1))

#plt.show()
ax.legend(title ='Mutant growth rate', loc = 'upper right')
ax.set_xlabel("Population Size (Log Scale)", fontsize = 13)
ax.set_ylabel(r"$P_\text{res}$", fontsize = 13)
ax.set_xscale('log')
ax.set_ylim(-0.1, 1.0)
plt.savefig("PR_neg_denisty_Approximation.png", format='png', bbox_inches="tight")
#plt.tight_layout()

# %%
def f(rm,rw): 
    C0 = 2*rm
    C1 = 2*rm*rw/(rm-rw) 
    xcut = 1 + rw*(1-rm)/(rm-2*rw+rw**2)
    H = (1-rw)*rw/((rw-rm)*rm)
    def f(x) : 
        Jt = (1/rm * hyp2f1_pq(-rm/rw, -1, x) - bm/bw * x/(1-rm/rw) * hyp2f1_pq(1-rm/rw, 0,x) 
        #Jt = Jt/  ( 1 -x )
        return 1-x+Jt
          
    return quad(f(x), 0, 1)[0] #2*(1+Jt)**(-1)


    #return -C1*xcut - (C1+C0)*xcut +2*H**(-1)*(1-xcut)


    

N0_rng = [ round(10**x) for x in np.arange(1,6,0.2) ] 
K_rng = [10**3,10**4,10**5]
K_rng = [round(10**x) for x in np.arange(3,5,0.2)]
sm_rng = np.arange(0.02,0.06,0.005)
colors = ["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728", "#9467bd", "#8c564b", "#e377c2"]

#fig, ax = plt.subplots(1,1,figsize = (5,4))
rm_true = []
rm_inferred = [] 

K_true = []
K_inferred1 = [] 
K_inferred2 = [] 
NoR  = 10**4

for K in K_rng:
    for sm_ind, sm in enumerate(sm_rng) : 
        print(K,sm)
        bw = 0.5 + np.log(0.95)/2
        bm = 0.5 + np.log(1 + sm)/2
        dw = 0.5 - np.log(0.95)/2
        dm = 0.5 - np.log(1+ sm)/2
        mu = 10**(-4)
        rw = bw-dw
        rm = bm-dm

        Pres_rng = [np.random.binomial(NoR, Pres(bw,dw,bm,dm,K,N0,mu))/NoR for N0 in N0_rng]
        Pres_rng = np.array(Pres_rng) 
        Pres_rng = np.transpose(Pres_rng)

        theta0 = [0.001, 100]
        bounds = [(1e-9,None),(None,None)]
        theta, r2_2, nll2 = MLE_fit(N0_rng, Pres_rng, model2, theta0, bounds)
        
        rm_true += [rm]
        rm_inferred += [-rw*theta[0]/(2*mu*theta[1])]
        K_true += [K]
        K_inferred1 += [theta[0]/(2*mu*f(rm,rw))]
        K_inferred2 += [theta[0]/(2*mu*f(rm_inferred[-1],rw))]
        #rm_inferred = -rw*theta[0]/(2*mu*theta[1])
        #print(rm,rm_inferred)
        #K_inferred = theta[0]/(2*mu*f(rm_inferred,rw))
        #print(K,K_inferred)
        #plt.scatter(N0_rng, Pres_rng[0], facecolors='none', edgecolor = colors[sm_ind], s=5, label = str(sm)) #, label = 'Time Integral'
        #plt.plot(N0_rng, [model2(N0,theta) for N0 in N0_rng], color = colors[sm_ind])
        #plt.xscale('log')
    #ax.plot(N0_rng, Pres_rng[1], linestyle = '--', color = colors[sm_ind]) #, label = 'Density Integral'
        #plt.plot(N0_rng, [Pres_theory3(bw,dw,bm,dm,K,N0,mu) for N0 in N0_rng], color = colors[sm_ind]) #, label = 'Model 2 (Exact $P_\text{res}$)'

fig, ax = plt.subplots(1,3, figsize = (10,3))
ax[0].scatter(rm_true, rm_inferred)
ax[0].plot(rm_true,rm_true, linestyle = '--', color= 'black')
#ax[0].set_xlim(min(rm_true)-0.01 , max(rm_true) +0.01 )
#ax[0].set_ylim(min(rm_true)-0.1 , max(rm_true) +0.1 )
ax[0].set_xlabel(r"True $r_m$")
ax[0].set_ylabel(r"Inferred $r_m$")

ax[1].scatter(K_true, K_inferred1)
ax[1].plot(K_true,K_true, linestyle = '--', color= 'black')
ax[1].set_xscale('log')
ax[1].set_yscale('log')
ax[1].set_xlabel(r"True $K$")
ax[1].set_ylabel(r"Inferred $K$ (Using true $r_m$)")

ax[2].scatter(K_true, K_inferred2)
ax[2].plot(K_true,K_true, linestyle = '--', color= 'black')
ax[2].set_xscale('log')
ax[2].set_yscale('log')
ax[2].set_xlabel(r"True $K$")
ax[2].set_ylabel(r"Inferred $K$ (Using inferred $r_m$)")

plt.tight_layout()
#plt.show()
#ax.legend(title ='Mutant growth rate', loc = 'upper right')
#ax.set_xlabel("Population Size (Log Scale)", fontsize = 13)
#ax.set_ylabel(r"$P_\text{res}$", fontsize = 13)

#ax.set_ylim(-0.1, 1.0)
#plt.savefig("PR_neg_denisty_Approximation.png", format='png', bbox_inches="tight")
#plt.tight_layout()
# Out:
# 1000 0.02
# 1000 0.025
# 1000 0.030000000000000002
# 1000 0.035
# 1000 0.04000000000000001
# 1000 0.045000000000000005
# 1000 0.05
# 1000 0.05500000000000001
# 1585 0.02
# 1585 0.025
# 1585 0.030000000000000002
# 1585 0.035
# 1585 0.04000000000000001
# 1585 0.045000000000000005
# 1585 0.05
# 1585 0.05500000000000001
# 2512 0.02
# 2512 0.025
# 2512 0.030000000000000002
# 2512 0.035
# 2512 0.04000000000000001
# 2512 0.045000000000000005
# 2512 0.05
# 2512 0.05500000000000001
# 3981 0.02
# 3981 0.025
# 3981 0.030000000000000002
# 3981 0.035
# 3981 0.04000000000000001
# 3981 0.045000000000000005
# 3981 0.05
# 3981 0.05500000000000001
# 6310 0.02
# 6310 0.025
# 6310 0.030000000000000002
# 6310 0.035
# 6310 0.04000000000000001
# 6310 0.045000000000000005
# 6310 0.05
# 6310 0.05500000000000001
# 10000 0.02
# 10000 0.025
# 10000 0.030000000000000002
# 10000 0.035
# 10000 0.04000000000000001
# 10000 0.045000000000000005
# 10000 0.05
# 10000 0.05500000000000001
# 15849 0.02
# 15849 0.025
# ...

# %%
fig, ax = plt.subplots(1,2, figsize = (10,5))
ax[0].scatter(rm_true, rm_inferred)
ax[0].plot(rm_true,rm_true, linestyle = '--', color= 'black')
ax[0].set_xlim(min(rm_true)-0.01 , max(rm_true) +0.01 )
ax[0].set_ylim(min(rm_true)-0.1 , max(rm_true) +0.1 )

ax[1].scatter(K_true, K_inferred)
ax[1].plot(K_true,K_true, linestyle = '--', color= 'black')

# %%
def integrand_alt(x): 
    rw = bw-dw
    Kw = (1-dw/bw)*K
    return mu*Kw*pest(x,bw,dw,bm,dm,K,10, var='x')/(rw*(1-x)) 

K = 10**4
bw = 0.5 + np.log(0.95)/2
bm = 0.5 + np.log(1.5)/2
dw = 0.5 - np.log(0.95)/2
dm = 0.5 - np.log(1.5)/2
mu = 10**(-4)
Kw = K*(bw-dw)/bw
rm = bm-dm 
rw = bw-dw
xrng = np.arange(0,1,0.00001)
yrng = [integrand_alt(x) for x in xrng]
plt.plot(xrng,yrng)
xrng1 = xrng[xrng <= 0.95]
plt.plot(xrng1, [ rm/bm*( 1 + dm/bw * rw/(rm-rw) * x )/(1-x)*mu*Kw/rw for x in xrng1], color = 'red', linestyle = '--')
H = (bm+dm)/rm * hyp2f1_pq(-rm/rw, -bm/bw, 1) - bm/bw * 1/(1-rm/rw) * hyp2f1_pq(1-rm/rw, 1-bm/bw,1) 
xrng2 = xrng[xrng > 0.4]
yrng2 = [( 2*H**(-1)*(1-x)**(bm/bw) - 2*H**(-2)*(1-x)**(2*bm/bw))/(1-x)*mu*Kw/rw  for x in xrng2  ]
#plt.plot(xrng2, yrng2)
yrng2 = [ 2*H**(-1)*(1-x)**(bm/bw)/(1-x)*mu*Kw/rw   for x in xrng2  ]
plt.plot(xrng2, yrng2)
plt.ylabel( r"$p_\text{est}(x)$" )
plt.xlabel( r"x" )

plt.axhline(y=0, color = 'black')
#plt.ylim([-0.1,1.5])
plt.show()

rw = bw-dw
rm = bm-dm

plt.plot(xrng, [pest(x,bw,dw,bm,dm,K,10, var='x') for x in xrng])
xrng1 = xrng[xrng <= 0.95]
plt.plot(xrng1, [ rm/bm*( 1 + dm/bw * rw/(rm-rw) * x ) for x in xrng1], color = 'red', linestyle = '--')
H = (bm+dm)/rm * hyp2f1_pq(-rm/rw, -bm/bw, 1) - bm/bw * 1/(1-rm/rw) * hyp2f1_pq(1-rm/rw, 1-bm/bw,1) 
xrng2 = xrng[xrng > 0.4]
yrng2 = [ 2*H**(-1)*(1-x)**(bm/bw) - 2*H**(-2)*(1-x)**(2*bm/bw)  for x in xrng2  ]
#plt.plot(xrng2, yrng2)
yrng2 = [ 2*H**(-1)*(1-x)**(bm/bw)   for x in xrng2  ]
plt.plot(xrng2, yrng2)
plt.ylabel( r"$p_\text{est}(x)$" )
plt.xlabel( r"x" )
plt.ylim([-0.01,1.01])
# Out:
# (-0.01, 1.01)
